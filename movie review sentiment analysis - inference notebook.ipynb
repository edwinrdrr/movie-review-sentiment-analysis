# %% [markdown]
# # 1 - Importing Libraries

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# # 2 - Loading the model

# %%
model_infer = tf.keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/P2M2 test inference/MovieReviewClassifier", compile=False)

# %% [markdown]
# # 3 - Predicting the review

# %%
np.where(model_infer.predict(["this is a bad movie."]) >= 0.5, 1, 0)
# Out:
# 1/1 [==============================] - 0s 279ms/step
# array([[0]])
